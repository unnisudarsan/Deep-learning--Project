# %%
import cv2

# Load the cascade
face_cascade = cv2.CascadeClassifier('/home/user/Downloads/Deep/haarcascade_frontalface_default.xml')

# %%
face_cascade
# Out:
# <CascadeClassifier 0x7f3a84405e10>

# %%
# Read the input image
img = cv2.imread('/home/user/Downloads/Deep/peoples1.png')
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4,minSize = (30,30))

# %%
# Show Image
cv2.namedWindow('Peoples', cv2.WINDOW_AUTOSIZE)
cv2.imshow('Peoples', img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
# ?face_cascade.detectMultiScale

# %%
faces
# Out:
# array([[387,  69,  64,  64],
#        [600,  60,  65,  65],
#        [173,  66,  71,  71],
#        [ 46, 108,  63,  63],
#        [271, 110,  71,  71],
#        [463, 117,  68,  68]], dtype=int32)

# %%
len(faces)
# Out:
# 6

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x-5, y-5), (x+w+5, y+h+5), (0, 0, 255), 2)

# %%
# Show Image
cv2.namedWindow('People', cv2.WINDOW_AUTOSIZE)
cv2.imshow('People', img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
eye_cascade = cv2.CascadeClassifier('/home/user/Downloads/Deep/haarcascade_eye.xml')

# %%
eye_cascade
# Out:
# <CascadeClassifier 0x7f3a53474db0>

# %%
# Read the input image
img = cv2.imread('/home/user/Downloads/Deep/peoples1.png')
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Detect faces
eye = eye_cascade.detectMultiScale(gray, 1.1, 4,minSize = (30,30))

# %%
# Show Image
cv2.namedWindow('Peoples', cv2.WINDOW_AUTOSIZE)
cv2.imshow('Peoples', img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
len(eye)
# Out:
# 2

# %%
img = cv2.imread('/home/user/Downloads/Deep/peoples1.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.1, 10,minSize = (15,15))
# When no faces detected, face_classifier returns and empty tuple
if faces is ():
    print("No Face Found")
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
    roi_gray = gray[y:y+h, x:x+w] #cropiing the face
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray,minSize=(1,1)) #checking for eye within the face
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)
# Out:
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-15-71753c1e545f>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# Show Image
cv2.namedWindow('People', cv2.WINDOW_AUTOSIZE)
cv2.imshow('People', img)
cv2.waitKey(20000)
cv2.destroyAllWindows()

# %%
video_capture = cv2.VideoCapture(0)
#video_capture = cv2.VideoCapture('data/laugh.mp4')

while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    print(ret)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=9,
        minSize=(45, 45)
    )

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        #cv2.rectangle(img,(x,y),(x+w,y+h),(127,0,255),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
        

    # Display the resulting frame
    cv2.imshow('Video', frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break
# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
